# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("farmacie.sicilia.csv", sep=",")

# %%
print(df.head())  # Mostra le prime righe
print(df.info())  # Informazioni sulle colonne
# Out:
#       COMUNE                   FARMACIA CL  \
# 0  AGRIGENTO             Averna Antonio  U
# 1  AGRIGENTO                Bajo Ettore  U
# 2  AGRIGENTO        Bruccoleri Raffaele  U
# 3  AGRIGENTO         Di Mino Rosa Maria  U
# 4  AGRIGENTO  Farmacia Camilleri S.N.C.  U
#
#                                  INDIRIZZO    CAP     TELEFONO  PROVINCIA
# 0                          Via Atenea, 325  92100   0922-26093  Agrigento
# 1            Piazza Primavera - Fontanelle  92100  0922-603966  Agrigento
# 2              Viale Viareggio - San Leone  92100  0922-413585  Agrigento
# 3  Viale Leonardo Sciascia - Villagio Mosè  92100  0922-607039  Agrigento
# 4              Viale Leonardo Sciascia, 28  92100  0922-606849  Agrigento
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1452 entries, 0 to 1451
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   COMUNE     1452 non-null   object
# ...

# %%
farmacia_per_provincia = df['PROVINCIA'].value_counts()
# Crea un grafico a barre utilizzando plt.bar()

plt.figure(figsize=(10, 6))
plt.bar(farmacia_per_provincia.index, farmacia_per_provincia.values, color='skyblue')

# Aggiungi il titolo e le etichette degli assi
plt.title("Numero di farmacie per provincia in Sicilia")
plt.xlabel("Provincia")
plt.ylabel("Numero di farmacie")

# Ruota le etichette sull'asse x per una migliore visibilità
plt.xticks(rotation=90)

# Mostra il grafico
plt.show()

# %%
# Filtra il DataFrame per la provincia di Agrigento
df_agrigento = df[df['PROVINCIA'] == 'Agrigento']

# Conta il numero di farmacie per comune nella provincia di Agrigento
farmacia_per_comune_agrigento = df_agrigento['COMUNE'].value_counts()

# Crea il grafico a barre
plt.figure(figsize=(10, 6))
plt.bar(farmacia_per_comune_agrigento.index, farmacia_per_comune_agrigento.values, color='skyblue')

# Aggiungi il titolo e le etichette degli assi
plt.title("Distribuzione delle farmacie nella provincia di Agrigento")
plt.xlabel("Comune")
plt.ylabel("Numero di farmacie")

# Ruota le etichette sull'asse x per una migliore visibilità
plt.xticks(rotation=90)

# Mostra il grafico
plt.show()

# %%
# Filtra il DataFrame per la provincia di Agrigento
df_agrigento = df[df['PROVINCIA'] == 'Agrigento']

# Conta il numero di farmacie per comune nella provincia di Agrigento
farmacia_per_comune_agrigento = df_agrigento['COMUNE'].value_counts()

# Crea il grafico a barre
plt.figure(figsize=(10, 6))
plt.bar(farmacia_per_comune_agrigento.index, farmacia_per_comune_agrigento.values, color='skyblue')

# Aggiungi il titolo e le etichette degli assi
plt.title("Distribuzione delle farmacie nella provincia di Agrigento")
plt.xlabel("Comune")
plt.ylabel("Numero di farmacie")

# Ruota le etichette sull'asse x per una migliore visibilità
plt.xticks(rotation=90)

# Mostra il grafico
plt.show()

# %%
# Filtra il DataFrame per la provincia di Agrigento
df_CL = df[df['PROVINCIA'] == 'Caltanissetta']

# Conta il numero di farmacie per comune nella provincia di Agrigento
farmacia_CL = df_CL['COMUNE'].value_counts()

# Crea il grafico a barre
plt.figure(figsize=(10, 6))
plt.bar(farmacia_CL.index, farmacia_CL.values, color='skyblue')

# Aggiungi il titolo e le etichette degli assi
plt.title("Distribuzione delle farmacie nella provincia di Caltanissetta")
plt.xlabel("Comune")
plt.ylabel("Numero di farmacie")

# Ruota le etichette sull'asse x per una migliore visibilità
plt.xticks(rotation=90)

# Mostra il grafico
plt.show()

# %%
# Filtra il DataFrame per la provincia di Agrigento
df_agrigento = df[df['PROVINCIA'] == 'Agrigento']

# Conta il numero di farmacie per comune nella provincia di Agrigento
farmacia_per_comune_agrigento = df_agrigento['COMUNE'].value_counts()

# Crea il grafico a barre
plt.figure(figsize=(10, 6))
plt.bar(farmacia_per_comune_agrigento.index, farmacia_per_comune_agrigento.values, color='skyblue')

# Aggiungi il titolo e le etichette degli assi
plt.title("Distribuzione delle farmacie nella provincia di Agrigento")
plt.xlabel("Comune")
plt.ylabel("Numero di farmacie")

# Ruota le etichette sull'asse x per una migliore visibilità
plt.xticks(rotation=90)

# Mostra il grafico
plt.show()
